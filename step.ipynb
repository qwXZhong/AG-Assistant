# %% [markdown]
# 1、拉起游戏进程，定位游戏窗口

# %% [markdown]
# 2、尝试获取游戏窗口图像信息

# %% [markdown]
# 3、目前使用模板匹配方法，定位元素位置

# %% [markdown]
# 目前已经可以实现登录界面的点击操作 √

# %% [markdown]
# 下一步跳过主界面动画，完成每日任务操作，每个小的任务以主界面为起点，任何一个小任务完成后都应该返回主界面，失败任务跳出对应提示，同样尝试返回主界面，进行下一步操作 （正在编写）

# %% [markdown]
# 待优化：1、修改返回主界面的逻辑(已完成)
#         2、优化分支的鲁棒性，点击失败可返回上层
#         3、优化登陆加载界面的检测，增加使用“修复”按键的检测
#         4、优化返回，支持点击取消按钮，备用方案的点击位置待修改，有时会失效

# %% [markdown]
# 5、商店支持每周的指定碎片购买

# %% [markdown]
# 6、清体力支持活动界面的联防协议

# %% [markdown]
# 7、游园街支持每周跳舞

# %% [markdown]
# 8、完善mimier() 包括窗口界面加入相关的设置

# %% [markdown]
# 9、联合特勤 最后体力清完后的再次识别优化（可以只优化Log输出的东西）
